# %%
import numpy as np #importing 
import pandas as pd 
from sklearn.preprocessing import MinMaxScaler

# %%
potable = pd.read_csv("Outliers Removed Dataset.csv") #reading the dataset

# %%
potable.head()
# Out:
#          ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0  5.971861  204.890456  20791.31898     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.05786     6.635246  252.848888    592.885359
# 2  8.099124  224.236259  19909.54173     9.275884  252.848888    418.606213
# 3  8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436525       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
potable.isna().sum() #checking for null values
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
potable.corr()
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.114479 -0.068651    -0.056495  0.002488
# Hardness         0.114479  1.000000 -0.041834    -0.015009 -0.062538
# Solids          -0.068651 -0.041834  1.000000    -0.054112 -0.096172
# Chloramines     -0.056495 -0.015009 -0.054112     1.000000  0.031925
# Sulfate          0.002488 -0.062538 -0.096172     0.031925  1.000000
# Conductivity     0.017007 -0.042554  0.004741    -0.028601 -0.007258
# Organic_carbon   0.034068  0.003093  0.026791    -0.005055  0.028202
# Trihalomethanes  0.013524 -0.019687 -0.022719     0.010217 -0.021584
# Turbidity       -0.037659 -0.020118  0.022041    -0.013929 -0.005207
# Potability       0.012708 -0.001671  0.016882     0.027125  0.004697
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.017007        0.034068         0.013524  -0.037659
# ...

# %%
x = potable.loc[: , 'ph' : 'Turbidity'] #input values

# %%
x
# Out:
#             ph    Hardness       Solids  Chloramines     Sulfate  \
# 0     5.971861  204.890456  20791.31898     7.300212  368.516441
# 1     3.716080  129.422921  18630.05786     6.635246  252.848888
# 2     8.099124  224.236259  19909.54173     9.275884  252.848888
# 3     8.316766  214.373394  22018.41744     8.059332  356.886136
# 4     9.092223  181.101509  17978.98634     6.546600  310.135738
# ...        ...         ...          ...          ...         ...
# 2881  6.069616  186.659040  26138.78019     7.747547  345.700257
# 2882  7.808856  193.553212  17329.80216     8.061362  256.321194
# 2883  9.419510  175.762646  33155.57822     7.350233  256.321194
# 2884  5.126763  230.603758  11983.86938     6.303357  256.321194
# 2885  7.874671  195.102299  17404.17706     7.509306  256.321194
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# ...

# %%
y = potable['Potability'] #target variable

# %%
x
# Out:
#             ph    Hardness       Solids  Chloramines     Sulfate  \
# 0     5.971861  204.890456  20791.31898     7.300212  368.516441
# 1     3.716080  129.422921  18630.05786     6.635246  252.848888
# 2     8.099124  224.236259  19909.54173     9.275884  252.848888
# 3     8.316766  214.373394  22018.41744     8.059332  356.886136
# 4     9.092223  181.101509  17978.98634     6.546600  310.135738
# ...        ...         ...          ...          ...         ...
# 2881  6.069616  186.659040  26138.78019     7.747547  345.700257
# 2882  7.808856  193.553212  17329.80216     8.061362  256.321194
# 2883  9.419510  175.762646  33155.57822     7.350233  256.321194
# 2884  5.126763  230.603758  11983.86938     6.303357  256.321194
# 2885  7.874671  195.102299  17404.17706     7.509306  256.321194
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2881    1
# 2882    1
# 2883    1
# 2884    1
# 2885    1
# Name: Potability, Length: 2886, dtype: int64

# %%
scaler = MinMaxScaler() #scaler

# %%
x_scaled = scaler.fit_transform(x)#scaling the xvalues

# %%
x_scaled
# Out:
# array([[0.3731538 , 0.55057199, 0.46909804, ..., 0.27466791, 0.75730416,
#         0.25799562],
#        [0.06256568, 0.0460109 , 0.4195707 , ..., 0.54552631, 0.36659662,
#         0.62172861],
#        [0.66604703, 0.67991423, 0.44889128, ..., 0.64080881, 0.49518086,
#         0.27994903],
#        ...,
#        [0.84784497, 0.35582919, 0.75243674, ..., 0.3118689 , 0.53882766,
#         0.33742202],
#        [0.25679617, 0.72248607, 0.267267  , ..., 0.31919733, 0.63621579,
#         0.67093591],
#        [0.63514314, 0.4851303 , 0.39147848, ..., 0.5997154 , 0.65163712,
#         0.10328137]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0. , random_state=42)
x_scaled_train , x_scaled_test , y_train , y_test = train_test_split(x , y , test_size = 0.3 , random_state=42)

# %%
clf = DecisionTreeClassifier(max_leaf_nodes=20 , random_state=0) 
# rfc = RandomForestClassifier(n_estimators=100 , random_state=0)

# %%
# clf.fit(x_train , y_train)
clf.fit(x_scaled_train , y_train) #training the model
# rfc.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=20, random_state=0)

# %%
# y_pred = clf.predict(x_test)
y_pred = clf.predict(x_scaled_test)

# y_pred = rfc.predict(x_test)

# %%
accuracy = accuracy_score(y_test , y_pred )

# %%
print(f"Accuracy : {accuracy: .2f}") #accuracy of the model
# Out:
# Accuracy :  0.79
